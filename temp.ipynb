# %%
import xarray as xr

# %%
f = xr.open_dataset('C://Users/Mathew.Biddle/Downloads/raw.nc')
f
# Out:
# <xarray.Dataset>
# Dimensions:           (profile: 52, z: 540)
# Coordinates:
#   * profile           (profile) object 'cen1a' 'cen1b-1' ... 'hc3-1' 'hc70-2'
#   * z                 (z) float32 0.989 1.979 2.969 2.97 ... 84.11 85.1 91.03
#     time              (profile) datetime64[ns] ...
#     latitude          (profile) float32 ...
#     longitude         (profile) float32 ...
# Data variables:
#     temperature       (profile, z) float32 ...
#     pressure          (profile, z) float32 ...
#     salinity          (profile, z) float32 ...
#     fluorescence      (profile, z) float32 ...
#     turbidity         (profile, z) float32 ...
#     dissolved_oxygen  (profile, z) float32 ...
#     transmissivity    (profile, z) float32 ...
# Attributes:
#     Conventions:                   CF-1.6
#     Metadata_conventions:          Unidata Dataset Discovery v1.0
#     standard_name_vocabulary:      CF-1.6
#     featureType:                   Profile
# ...
