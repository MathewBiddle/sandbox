# %%
import xarray as xr

# %%
f = xr.open_dataset('C://Users/Mathew.Biddle/Downloads/A0101.met.merged.nc')
f
# Out:
# C:\Users\Mathew.Biddle\programs\Anaconda3\envs\temp\lib\site-packages\xarray\conventions.py:492: SerializationWarning: variable 'wind_speed_qc_tests' has multiple fill values {'0', b'0'}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# C:\Users\Mathew.Biddle\programs\Anaconda3\envs\temp\lib\site-packages\xarray\conventions.py:492: SerializationWarning: variable 'wind_gust_qc_tests' has multiple fill values {'0', b'0'}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# C:\Users\Mathew.Biddle\programs\Anaconda3\envs\temp\lib\site-packages\xarray\conventions.py:492: SerializationWarning: variable 'wind_direction_qc_tests' has multiple fill values {'0', b'0'}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# C:\Users\Mathew.Biddle\programs\Anaconda3\envs\temp\lib\site-packages\xarray\conventions.py:492: SerializationWarning: variable 'air_temperature_qc_tests' has multiple fill values {'0', b'0'}, decoding all values to NaN.
# ...

# %%
f.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	time = 5793 ;
#
# variables:
# 	float64 lat() ;
# 		lat:long_name = Latitude in decimal degrees north ;
# 		lat:standard_name = latitude ;
# 		lat:standard_name_url = https://vocab.nerc.ac.uk/collection/P07/current/CFSN0600 ;
# 		lat:short_name = lat ;
# 		lat:units = degrees_north ;
# 		lat:valid_range = [-90.  90.] ;
# 		lat:epic_code = 500 ;
# 		lat:axis = Y ;
# 		lat:ioos_category = location ;
# 		lat:echo = 42.5183 ;
# 		lat:comment = Coordinate variable ;
# 	float64 lon() ;
# 		lon:long_name = Longitude in decimal degrees east ;
# 		lon:standard_name = longitude ;
# 		lon:standard_name_url = https://vocab.nerc.ac.uk/collection/P07/current/CFSN0554 ;
# 		lon:short_name = lon ;
# 		lon:modulo = 360.0 ;
# 		lon:units = degrees_east ;
# 		lon:valid_range = [-180.  180.] ;
# 		lon:epic_code = 502 ;
# 		lon:axis = X ;
# 		lon:ioos_category = location ;
# 		lon:echo = -70.5655 ;
# 		lon:comment = Coordinate variable ;
# 	float64 depth() ;
# ...

# %%
f.variables['time']
# Out:
# <xarray.IndexVariable 'time' (time: 4390)>
# array(['2001-07-10T03:00:00.000000000', '2001-07-10T04:00:00.000000000',
#        '2001-07-10T05:00:00.000000000', ..., '2002-01-08T22:00:00.000000000',
#        '2002-01-08T23:00:00.000000000', '2002-01-09T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Attributes:
#     long_name:          Time
#     standard_name:      time
#     standard_name_url:  https://vocab.nerc.ac.uk/collection/P07/current/CFSN0115
#     short_name:         time
#     valid_range:        [0.00000000e+00 2.14748365e+09]
#     epic_code:          624
#     ioos_category:      Time
#     axis:               T
#     comment:            Coordinate variable, nominal time of observation

# %%
f.plot.scatter(x='time',y='current_speed')
