# %%
import pandas as pd

# %%
occurrence_files = ['./AMBON/AMBON2015_zooplankton/AMBON2015_zooplankton_Occurrence_DWC.csv',
                   './AMBON/AMBON2017_zooplankton/AMBON2017_zooplankton_Occurrence_DWC.csv']

for file in occurrence_files:
    df = pd.read_csv(file)
    print("File:%s\n%s\n"%(file,df['lifeStage'].unique()))
    df.drop(columns='Unnamed: 0',inplace=True)
    
    # find where lifeStage is either 'male' or 'female' and return that to another column called 'sex'
    df['sex'] = df.loc[ (df['lifeStage'] == 'male') | (df['lifeStage'] == 'female'), ['lifeStage'] ]
    df.loc[ (df['lifeStage'] == 'male'), ['lifeStage']] = ''
    df.loc[ (df['lifeStage'] == 'female'), ['lifeStage']] = ''
    
    fname = file.replace('_DWC','_DWC_mb')
    df.to_csv(fname, index=False)

# %% [markdown]
# Get the data from OBIS API and try to fix the occurrenceID, among other things.
#
# See also, `../AMBON/2017zooplanton_to_dwc(2)_mmb.ipynb`

# %%
# Import requests and set the OBIS API base URL. 
import requests
import json
import pandas as pd
import urllib

# Convenience function to pretty print JSON objects
def print_json(myjson):
    print(json.dumps(
        myjson,
        sort_keys=True,
        indent=4,
        separators=(',', ': ')
    ))
    

# Initialize the base URL for OBIS. This variable will be used for every API call
OBIS_URL = "https://api.obis.org/v3"

req = requests.get(f'{OBIS_URL}/node')
nodes_json = req.json()

df_nodes = pd.DataFrame(nodes_json['results'])
df_nodes[['name','id']]

nodeID = df_nodes.loc[df_nodes['name']=='OBIS USA','id'].tolist()[0]
# node/{nodeID}
req = requests.get(f'{OBIS_URL}/node/{nodeID}')
obis_usa_json = req.json()

# Show OBIS-USA node record
print_json(obis_usa_json)
# Out:
# {
#     "results": [
#         {
#             "contacts": [
#                 {
#                     "email": "albenson@usgs.gov",
#                     "givenname": "Abby",
#                     "oceanexpert_id": 25483,
#                     "surname": "Benson"
#                 },
#                 {
#                     "email": "sbristol@usgs.gov",
#                     "givenname": "Sky",
#                     "oceanexpert_id": 25731,
#                     "surname": "Bristol"
#                 }
#             ],
#             "description": "Ocean Biodiversity Information System USA (OBIS-USA) brings together marine biological observation data \u2013 recorded observations of identifiable marine species at a known time and place, collected primarily from U.S. Waters or with U.S. funding.",
#             "feeds": [
#                 {
#                     "id": "753ce293-c4c0-4ee5-bf22-361db7b89e3a",
#                     "url": "https://ipt.geome-db.org/rss.do"
#                 },
#                 {
#                     "id": "8112d75b-7e78-4641-9e09-9a2cc7db7375",
#                     "url": "https://www1.usgs.gov/obis-usa/ipt/rss.do"
#                 }
#             ],
#             "id": "b7c47783-a020-4173-b390-7b57c4fa1426",
#             "lat": 40.0069147,
#             "logo": null,
#             "lon": -105.2749529,
#             "name": "OBIS USA",
#             "theme": "",
#             "type": "regional",
#             "url": [
#                 "https://www.usgs.gov/obis-usa"
#             ]
#         }
#     ],
#     "total": 1
# }

# %%
req = requests.get(f'{OBIS_URL}/dataset?nodeid={nodeID}')
datasets = req.json()

# %%
# dataset
GBIF_URL = 'https://api.gbif.org/v1'
GBIF_UUID = '7afb6dbd-6485-42c2-aee7-c730bd81d2cd'


req = requests.get(f'{GBIF_URL}/dataset/{GBIF_UUID}/endpoint')

req.json()


# create a random id for occurrence
# put occurrenceID into emof.
# Out:
# [{'key': 627708,
#   'type': 'DWC_ARCHIVE',
#   'url': 'https://www1.usgs.gov/obis-usa/ipt/archive.do?r=ambon_zooplankton_2017',
#   'createdBy': 'c3ad790a-d426-4ac1-8e32-da61f81f0117',
#   'modifiedBy': 'c3ad790a-d426-4ac1-8e32-da61f81f0117',
#   'created': '2021-08-27T20:56:42.963+00:00',
#   'modified': '2021-08-27T20:56:42.963+00:00',
#   'machineTags': []},
#  {'key': 627707,
#   'type': 'EML',
#   'url': 'https://www1.usgs.gov/obis-usa/ipt/eml.do?r=ambon_zooplankton_2017',
#   'createdBy': 'c3ad790a-d426-4ac1-8e32-da61f81f0117',
#   'modifiedBy': 'c3ad790a-d426-4ac1-8e32-da61f81f0117',
#   'created': '2021-08-27T20:56:42.867+00:00',
#   'modified': '2021-08-27T20:56:42.867+00:00',
#   'machineTags': []}]

# %%
for endpoint in req.json():
    if endpoint['type'] == 'EML':
        r = requests.get(endpoint['url'], allow_redirects=True)
        open(endpoint['url'].split("=")[-1]+'.zip', 'wb').write(r.content)

# %%
obis_uuid = 'bc01451e-d990-4ad1-8315-e3fb6e9cf461'
ipt_id = 'ambon_zooplankton_2017'

req = requests.get(f'{OBIS_URL}/dataset/{obis_uuid}')

req = requests.get(f'{OBIS_URL}/occurrence?datasetid={obis_uuid}&mof=true&size=5000')

req.json()
# Out:
# {'total': 4727,
#  'results': [{'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:103413',
#    'scientificName': 'Oikopleura (Vexillaria) labradoriensis',
#    'dropped': False,
#    'aphiaID': 103413,
#    'decimalLatitude': 68.8984,
#    'phylumid': 1821,
#    'familyid': 103356,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'tribeid': 343701,
#    'maximumDepthInMeters': 29,
#    'id': '001bc0c8-d7c0-420c-9b61-94cb1ae6f6c9',
#    'order': 'Copelata',
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -166.4237,
#    'date_end': 1502150400000,
#    'speciesid': 103413,
#    'occurrenceID': 'AMBON_Zooplankton_2017_CL0_4336',
#    'date_start': 1502150400000,
#    'genus': 'Oikopleura',
#    'tribe': 'Labiata',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'eventDate': '2017-08-08 15:46:00',
#    'eventID': 'AMBON_Zooplankton_2017_CL0_2017-08-08T15:46:00Z',
#    'absence': False,
#    'subfamily': 'Oikopleurinae',
#    'genusid': 103367,
#    'taxonID': '103413',
#    'originalScientificName': 'Oikopleura labradoriensis',
#    'marine': True,
#    'minimumDepthInMeters': 29,
#    'subphylumid': 146420,
#    'subfamilyid': 342464,
#    'countryCode': 'US',
#    'date_mid': 1502150400000,
#    'subgenus': 'Oikopleura (Vexillaria)',
#    'class': 'Appendicularia',
#    'identificationReferences': 'WoRMS',
#    'orderid': 103353,
#    'geodeticDatum': 'WGS84',
#    'kingdom': 'Animalia',
#    'subgenusid': 343702,
#    'classid': 146421,
#    'depth': 29,
#    'phylum': 'Chordata',
#    'species': 'Oikopleura (Vexillaria) labradoriensis',
#    'subphylum': 'Tunicata',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'family': 'Oikopleuridae',
#    'kingdomid': 2,
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.65,
#    'shoredistance': 8316,
#    'sst': 1.6,
#    'bathymetry': 20,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_BBL1_2017-08-20T22:48:00Z',
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:117849',
#    'scientificName': 'Aglantha digitale',
#    'absence': False,
#    'dropped': False,
#    'genusid': 117212,
#    'aphiaID': 117849,
#    'decimalLatitude': 69.3443,
#    'subclassid': 22754,
#    'taxonID': '117849',
#    'originalScientificName': 'Aglantha digitale',
#    'marine': True,
#    'minimumDepthInMeters': 12,
#    'phylumid': 1267,
#    'familyid': 16842,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': False,
#    'countryCode': 'US',
#    'date_mid': 1503187200000,
#    'maximumDepthInMeters': 12,
#    'id': '001db6e1-80fe-4e76-9014-f760731382ea',
#    'class': 'Hydrozoa',
#    'order': 'Trachymedusae',
#    'identificationReferences': 'WoRMS',
#    'orderid': 16350,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -163.5095,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1503187200000,
#    'speciesid': 117849,
#    'occurrenceID': 'AMBON_Zooplankton_2017_BBL1_4725',
#    'kingdom': 'Animalia',
#    'date_start': 1503187200000,
#    'classid': 1337,
#    'depth': 12,
#    'phylum': 'Cnidaria',
#    'genus': 'Aglantha',
#    'species': 'Aglantha digitale',
#    'subclass': 'Trachylinae',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'family': 'Rhopalonematidae',
#    'kingdomid': 2,
#    'eventDate': '2017-08-20 22:48:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 32.37,
#    'shoredistance': 11213,
#    'sst': 1.21,
#    'bathymetry': 14,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_ML1.9_2017-08-18T15:43:00Z',
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:117849',
#    'scientificName': 'Aglantha digitale',
#    'absence': False,
#    'dropped': False,
#    'genusid': 117212,
#    'aphiaID': 117849,
#    'decimalLatitude': 71.0213,
#    'subclassid': 22754,
#    'taxonID': '117849',
#    'originalScientificName': 'Aglantha digitale',
#    'marine': True,
#    'minimumDepthInMeters': 41,
#    'phylumid': 1267,
#    'familyid': 16842,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': False,
#    'countryCode': 'US',
#    'date_mid': 1503014400000,
#    'maximumDepthInMeters': 41,
#    'id': '0021d82d-f557-460b-bf14-002101769357',
#    'class': 'Hydrozoa',
#    'order': 'Trachymedusae',
#    'identificationReferences': 'WoRMS',
#    'orderid': 16350,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -165.635,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1503014400000,
#    'speciesid': 117849,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML1.9_4483',
#    'kingdom': 'Animalia',
#    'date_start': 1503014400000,
#    'classid': 1337,
#    'depth': 41,
#    'phylum': 'Cnidaria',
#    'genus': 'Aglantha',
#    'species': 'Aglantha digitale',
#    'subclass': 'Trachylinae',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'family': 'Rhopalonematidae',
#    'kingdomid': 2,
#    'eventDate': '2017-08-18 15:43:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.79,
#    'shoredistance': 152684,
#    'sst': 0.53,
#    'bathymetry': 41,
#    'mof': None},
#   {'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:104470',
#    'scientificName': 'Neocalanus cristatus',
#    'dropped': False,
#    'aphiaID': 104470,
#    'decimalLatitude': 67.7835,
#    'subclassid': 1080,
#    'phylumid': 1065,
#    'familyid': 104079,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': False,
#    'superclass': 'Multicrustacea',
#    'maximumDepthInMeters': 48,
#    'id': '003776ed-0b80-48b8-8ac0-fd2369ee5620',
#    'order': 'Calanoida',
#    'superclassid': 845959,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -168.605,
#    'date_end': 1503360000000,
#    'speciesid': 104470,
#    'occurrenceID': 'AMBON_Zooplankton_2017_DBO3.7_8392',
#    'date_start': 1503360000000,
#    'genus': 'Neocalanus',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'eventDate': '2017-08-22 03:47:00',
#    'eventID': 'AMBON_Zooplankton_2017_DBO3.7_2017-08-22T03:47:00Z',
#    'brackish': False,
#    'superorder': 'Gymnoplea',
#    'absence': False,
#    'superorderid': 155877,
#    'genusid': 104155,
#    'taxonID': '10419',
#    'originalScientificName': 'Metridia',
#    'marine': True,
#    'minimumDepthInMeters': 48,
#    'subphylumid': 1066,
#    'infraclassid': 155876,
#    'countryCode': 'US',
#    'date_mid': 1503360000000,
#    'infraclass': 'Neocopepoda',
#    'class': 'Hexanauplia',
#    'identificationReferences': 'WoRMS',
#    'orderid': 1100,
#    'geodeticDatum': 'WGS84',
#    'kingdom': 'Animalia',
#    'classid': 889925,
#    'depth': 48,
#    'phylum': 'Arthropoda',
#    'species': 'Neocalanus cristatus',
#    'subphylum': 'Crustacea',
#    'subclass': 'Copepoda',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'family': 'Calanidae',
#    'kingdomid': 2,
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 32.11,
#    'shoredistance': 95833,
#    'sst': 1.04,
#    'bathymetry': 47,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_ML6.2_2017-08-09T14:55:00Z',
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:1128',
#    'superorder': 'Eucarida',
#    'scientificName': 'Euphausiacea',
#    'absence': False,
#    'dropped': False,
#    'superorderid': 1089,
#    'aphiaID': 1128,
#    'decimalLatitude': 70.2647,
#    'subclassid': 1086,
#    'taxonID': '1128',
#    'originalScientificName': 'Euphausiacea',
#    'marine': True,
#    'minimumDepthInMeters': 29,
#    'phylumid': 1065,
#    'subphylumid': 1066,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'countryCode': 'US',
#    'superclass': 'Multicrustacea',
#    'date_mid': 1502236800000,
#    'maximumDepthInMeters': 29,
#    'id': '003bce44-6e53-440a-b2e5-b384fdabd8ac',
#    'class': 'Malacostraca',
#    'order': 'Euphausiacea',
#    'identificationReferences': 'WoRMS',
#    'superclassid': 845959,
#    'orderid': 1128,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -163.4139,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1502236800000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML6.2_9577',
#    'kingdom': 'Animalia',
#    'date_start': 1502236800000,
#    'classid': 1071,
#    'depth': 29,
#    'phylum': 'Arthropoda',
#    'lifeStage': 'furcilia',
#    'subphylum': 'Crustacea',
#    'subclass': 'Eumalacostraca',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'BONGO_505UM_MICROSCOPY',
#    'kingdomid': 2,
#    'eventDate': '2017-08-09 14:55:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.98,
#    'shoredistance': 38738,
#    'sst': 1.05,
#    'bathymetry': 31,
#    'mof': None},
#   {'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:103367',
#    'scientificName': 'Oikopleura',
#    'dropped': False,
#    'aphiaID': 103367,
#    'decimalLatitude': 70.9597,
#    'phylumid': 1821,
#    'familyid': 103356,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'tribeid': 343701,
#    'maximumDepthInMeters': 42,
#    'id': '0050cdb7-40ad-4c18-b459-014fe79ad4e2',
#    'order': 'Copelata',
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -161.1383,
#    'date_end': 1502323200000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML6.8_5892',
#    'date_start': 1502323200000,
#    'genus': 'Oikopleura',
#    'tribe': 'Labiata',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'eventDate': '2017-08-10 10:14:00',
#    'eventID': 'AMBON_Zooplankton_2017_ML6.8_2017-08-10T10:14:00Z',
#    'brackish': True,
#    'absence': False,
#    'subfamily': 'Oikopleurinae',
#    'genusid': 103367,
#    'taxonID': '103367',
#    'originalScientificName': 'Oikopleura',
#    'marine': True,
#    'minimumDepthInMeters': 42,
#    'subphylumid': 146420,
#    'subfamilyid': 342464,
#    'countryCode': 'US',
#    'date_mid': 1502323200000,
#    'class': 'Appendicularia',
#    'identificationReferences': 'WoRMS',
#    'orderid': 103353,
#    'geodeticDatum': 'WGS84',
#    'kingdom': 'Animalia',
#    'classid': 146421,
#    'depth': 42,
#    'phylum': 'Chordata',
#    'subphylum': 'Tunicata',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'family': 'Oikopleuridae',
#    'kingdomid': 2,
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.65,
#    'shoredistance': 53519,
#    'sst': 0.22,
#    'bathymetry': 44,
#    'mof': None},
#   {'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:104152',
#    'scientificName': 'Calanus',
#    'dropped': False,
#    'aphiaID': 104152,
#    'decimalLatitude': 71.5887,
#    'subclassid': 1080,
#    'phylumid': 1065,
#    'familyid': 104079,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': False,
#    'superclass': 'Multicrustacea',
#    'maximumDepthInMeters': 45,
#    'id': '0051d4ce-877b-4a83-832b-2c8897f949df',
#    'order': 'Calanoida',
#    'superclassid': 845959,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -161.4001,
#    'date_end': 1502582400000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML4.7_1244',
#    'date_start': 1502582400000,
#    'genus': 'Calanus',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'eventDate': '2017-08-13 01:27:00',
#    'eventID': 'AMBON_Zooplankton_2017_ML4.7_2017-08-13T01:27:00Z',
#    'brackish': False,
#    'superorder': 'Gymnoplea',
#    'absence': False,
#    'superorderid': 155877,
#    'genusid': 104152,
#    'taxonID': '19677',
#    'originalScientificName': 'Calanus glacialis/marshallae',
#    'marine': True,
#    'minimumDepthInMeters': 45,
#    'subphylumid': 1066,
#    'infraclassid': 155876,
#    'countryCode': 'US',
#    'date_mid': 1502582400000,
#    'infraclass': 'Neocopepoda',
#    'class': 'Hexanauplia',
#    'identificationReferences': 'WoRMS',
#    'orderid': 1100,
#    'geodeticDatum': 'WGS84',
#    'kingdom': 'Animalia',
#    'classid': 889925,
#    'depth': 45,
#    'phylum': 'Arthropoda',
#    'subphylum': 'Crustacea',
#    'subclass': 'Copepoda',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'family': 'Calanidae',
#    'kingdomid': 2,
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.57,
#    'shoredistance': 108198,
#    'sst': -0.32,
#    'bathymetry': 47,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_ML1.2_2017-08-17T17:42:00Z',
#    'brackish': True,
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:883',
#    'scientificName': 'Polychaeta',
#    'absence': False,
#    'dropped': False,
#    'aphiaID': 883,
#    'decimalLatitude': 70.1388,
#    'taxonID': '883',
#    'originalScientificName': 'Polychaeta',
#    'marine': True,
#    'minimumDepthInMeters': 20,
#    'phylumid': 882,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': True,
#    'countryCode': 'US',
#    'date_mid': 1502928000000,
#    'maximumDepthInMeters': 20,
#    'id': '006ee511-8df7-42fa-9c14-b411cd08c369',
#    'class': 'Polychaeta',
#    'identificationReferences': 'WoRMS',
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -163.0542,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1502928000000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML1.2_9589',
#    'kingdom': 'Animalia',
#    'date_start': 1502928000000,
#    'classid': 883,
#    'depth': 20,
#    'phylum': 'Annelida',
#    'lifeStage': 'larvae',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'kingdomid': 2,
#    'eventDate': '2017-08-17 17:42:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 32.24,
#    'shoredistance': 20056,
#    'sst': 1.04,
#    'bathymetry': 22,
#    'mof': None},
#   {'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:157951',
#    'scientificName': 'Halitholus cirratus',
#    'dropped': False,
#    'aphiaID': 157951,
#    'decimalLatitude': 72.1088,
#    'subclassid': 19494,
#    'phylumid': 1267,
#    'familyid': 15029,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': False,
#    'maximumDepthInMeters': 38,
#    'id': '007c1977-2a10-45b2-bea2-b64e657bf697',
#    'order': 'Anthoathecata',
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -162.9294,
#    'date_end': 1502582400000,
#    'speciesid': 157951,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML4.11_2327',
#    'suborderid': 16352,
#    'date_start': 1502582400000,
#    'genus': 'Halitholus',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'eventDate': '2017-08-13 14:54:00',
#    'eventID': 'AMBON_Zooplankton_2017_ML4.11_2017-08-13T14:54:00Z',
#    'brackish': True,
#    'absence': False,
#    'genusid': 117182,
#    'taxonID': '157951',
#    'originalScientificName': 'Halitholus cirratus',
#    'marine': True,
#    'minimumDepthInMeters': 38,
#    'countryCode': 'US',
#    'date_mid': 1502582400000,
#    'class': 'Hydrozoa',
#    'identificationReferences': 'WoRMS',
#    'suborder': 'Filifera',
#    'orderid': 13551,
#    'geodeticDatum': 'WGS84',
#    'kingdom': 'Animalia',
#    'classid': 1337,
#    'depth': 38,
#    'phylum': 'Cnidaria',
#    'species': 'Halitholus cirratus',
#    'subclass': 'Hydroidolina',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'family': 'Pandeidae',
#    'kingdomid': 2,
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.67,
#    'shoredistance': 186441,
#    'sst': -0.37,
#    'bathymetry': 38,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_ML3.3_2017-08-17T01:29:00Z',
#    'brackish': True,
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:1082',
#    'scientificName': 'Cirripedia',
#    'absence': False,
#    'dropped': False,
#    'aphiaID': 1082,
#    'decimalLatitude': 70.7147,
#    'subclassid': 1082,
#    'taxonID': '1082',
#    'originalScientificName': 'Cirripedia',
#    'marine': True,
#    'minimumDepthInMeters': 41,
#    'phylumid': 1065,
#    'subphylumid': 1066,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'countryCode': 'US',
#    'superclass': 'Multicrustacea',
#    'date_mid': 1502928000000,
#    'maximumDepthInMeters': 41,
#    'id': '007e0560-23b0-43cb-9e6a-5396614da7b7',
#    'class': 'Thecostraca',
#    'identificationReferences': 'WoRMS',
#    'superclassid': 845959,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -161.1734,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1502928000000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML3.3_8571',
#    'kingdom': 'Animalia',
#    'date_start': 1502928000000,
#    'classid': 22388,
#    'depth': 41,
#    'phylum': 'Arthropoda',
#    'lifeStage': 'nauplii',
#    'subphylum': 'Crustacea',
#    'subclass': 'Cirripedia',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'BONGO_505UM_MICROSCOPY',
#    'kingdomid': 2,
#    'eventDate': '2017-08-17 01:29:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.86,
#    'shoredistance': 37589,
#    'sst': 0.45,
#    'bathymetry': 41,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_ML4.14_2017-08-22T03:47:00Z',
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:117849',
#    'scientificName': 'Aglantha digitale',
#    'absence': False,
#    'dropped': False,
#    'genusid': 117212,
#    'aphiaID': 117849,
#    'decimalLatitude': 72.4964,
#    'subclassid': 22754,
#    'taxonID': '117849',
#    'originalScientificName': 'Aglantha digitale',
#    'marine': True,
#    'minimumDepthInMeters': 47,
#    'phylumid': 1267,
#    'familyid': 16842,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': False,
#    'countryCode': 'US',
#    'date_mid': 1503360000000,
#    'maximumDepthInMeters': 47,
#    'id': '007faa4f-cad3-460c-9837-5a7f8c233fae',
#    'class': 'Hydrozoa',
#    'order': 'Trachymedusae',
#    'identificationReferences': 'WoRMS',
#    'orderid': 16350,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -164.1022,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1503360000000,
#    'speciesid': 117849,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML4.14_9889',
#    'kingdom': 'Animalia',
#    'date_start': 1503360000000,
#    'classid': 1337,
#    'depth': 47,
#    'phylum': 'Cnidaria',
#    'genus': 'Aglantha',
#    'species': 'Aglantha digitale',
#    'subclass': 'Trachylinae',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'family': 'Rhopalonematidae',
#    'kingdomid': 2,
#    'eventDate': '2017-08-22 03:47:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.73,
#    'shoredistance': 244975,
#    'sst': -0.35,
#    'bathymetry': 50,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_DBO3.5_2017-08-07T05:34:00Z',
#    'brackish': False,
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:113',
#    'scientificName': 'Patellidae',
#    'absence': False,
#    'superfamilyid': 156481,
#    'dropped': False,
#    'aphiaID': 113,
#    'decimalLatitude': 68.009,
#    'subclassid': 382158,
#    'taxonID': '113',
#    'originalScientificName': 'Decapoda',
#    'marine': True,
#    'minimumDepthInMeters': 51,
#    'phylumid': 51,
#    'familyid': 113,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': False,
#    'countryCode': 'US',
#    'date_mid': 1502064000000,
#    'maximumDepthInMeters': 51,
#    'id': '00ba1590-5e7d-4999-a236-5401cc278e0e',
#    'class': 'Gastropoda',
#    'identificationReferences': 'WoRMS',
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -167.8681,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1502064000000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_DBO3.5_3730',
#    'superfamily': 'Patelloidea',
#    'kingdom': 'Animalia',
#    'date_start': 1502064000000,
#    'classid': 101,
#    'depth': 51,
#    'phylum': 'Mollusca',
#    'lifeStage': 'megalopa',
#    'subclass': 'Patellogastropoda',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'BONGO_505UM_MICROSCOPY',
#    'family': 'Patellidae',
#    'kingdomid': 2,
#    'eventDate': '2017-08-07 05:34:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.93,
#    'shoredistance': 56112,
#    'sst': 1.27,
#    'bathymetry': 53,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_ML4.2_2017-08-12T08:54:00Z',
#    'brackish': True,
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:1806',
#    'scientificName': 'Echinodermata',
#    'absence': False,
#    'dropped': False,
#    'aphiaID': 1806,
#    'decimalLatitude': 70.9327,
#    'taxonID': '1806',
#    'originalScientificName': 'Echinodermata',
#    'marine': True,
#    'minimumDepthInMeters': 43,
#    'phylumid': 1806,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'countryCode': 'US',
#    'date_mid': 1502496000000,
#    'maximumDepthInMeters': 43,
#    'id': '00d6c9f1-bce5-49d4-b032-8a708067a176',
#    'identificationReferences': 'WoRMS',
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -159.5049,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1502496000000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML4.2_6399',
#    'kingdom': 'Animalia',
#    'date_start': 1502496000000,
#    'depth': 43,
#    'phylum': 'Echinodermata',
#    'lifeStage': 'bipinnaria',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'kingdomid': 2,
#    'eventDate': '2017-08-12 08:54:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.81,
#    'shoredistance': 10951,
#    'sst': 0.04,
#    'bathymetry': 46,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_ML5.4_2017-08-20T01:09:00Z',
#    'brackish': True,
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:883',
#    'scientificName': 'Polychaeta',
#    'absence': False,
#    'dropped': False,
#    'aphiaID': 883,
#    'decimalLatitude': 71.0225,
#    'taxonID': '883',
#    'originalScientificName': 'Polychaeta',
#    'marine': True,
#    'minimumDepthInMeters': 33,
#    'phylumid': 882,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': True,
#    'countryCode': 'US',
#    'date_mid': 1503187200000,
#    'maximumDepthInMeters': 33,
#    'id': '00da71b7-46a0-455f-a7b9-ff6f354fe9d6',
#    'class': 'Polychaeta',
#    'identificationReferences': 'WoRMS',
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -164.8768,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1503187200000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML5.4_3302',
#    'kingdom': 'Animalia',
#    'date_start': 1503187200000,
#    'classid': 883,
#    'depth': 33,
#    'phylum': 'Annelida',
#    'lifeStage': 'larvae',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'kingdomid': 2,
#    'eventDate': '2017-08-20 01:09:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.74,
#    'shoredistance': 131551,
#    'sst': 0.42,
#    'bathymetry': 35,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_DBO3.5_2017-08-07T05:34:00Z',
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:1128',
#    'superorder': 'Eucarida',
#    'scientificName': 'Euphausiacea',
#    'absence': False,
#    'dropped': False,
#    'superorderid': 1089,
#    'aphiaID': 1128,
#    'decimalLatitude': 68.009,
#    'subclassid': 1086,
#    'taxonID': '1128',
#    'originalScientificName': 'Euphausiacea',
#    'marine': True,
#    'minimumDepthInMeters': 51,
#    'phylumid': 1065,
#    'subphylumid': 1066,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'countryCode': 'US',
#    'superclass': 'Multicrustacea',
#    'date_mid': 1502064000000,
#    'maximumDepthInMeters': 51,
#    'id': '00fa31a2-61a0-4600-a191-50bc494694e3',
#    'class': 'Malacostraca',
#    'order': 'Euphausiacea',
#    'identificationReferences': 'WoRMS',
#    'superclassid': 845959,
#    'orderid': 1128,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -167.8681,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1502064000000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_DBO3.5_6481',
#    'kingdom': 'Animalia',
#    'date_start': 1502064000000,
#    'classid': 1071,
#    'depth': 51,
#    'phylum': 'Arthropoda',
#    'lifeStage': 'juvenile',
#    'subphylum': 'Crustacea',
#    'subclass': 'Eumalacostraca',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'BONGO_505UM_MICROSCOPY',
#    'kingdomid': 2,
#    'eventDate': '2017-08-07 05:34:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.93,
#    'shoredistance': 56112,
#    'sst': 1.27,
#    'bathymetry': 53,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_DBO3.4_2017-08-22T03:47:00Z',
#    'brackish': False,
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:113',
#    'scientificName': 'Patellidae',
#    'absence': False,
#    'superfamilyid': 156481,
#    'dropped': False,
#    'aphiaID': 113,
#    'decimalLatitude': 68.1245,
#    'subclassid': 382158,
#    'taxonID': '113',
#    'originalScientificName': 'Decapoda',
#    'marine': True,
#    'minimumDepthInMeters': 48,
#    'phylumid': 51,
#    'familyid': 113,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': False,
#    'countryCode': 'US',
#    'date_mid': 1503360000000,
#    'maximumDepthInMeters': 48,
#    'id': '00fd1ef5-85d8-4623-ad05-ff7a02b37986',
#    'class': 'Gastropoda',
#    'identificationReferences': 'WoRMS',
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -167.4978,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1503360000000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_DBO3.4_1895',
#    'superfamily': 'Patelloidea',
#    'kingdom': 'Animalia',
#    'date_start': 1503360000000,
#    'classid': 101,
#    'depth': 48,
#    'phylum': 'Mollusca',
#    'lifeStage': 'megalopa',
#    'subclass': 'Patellogastropoda',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'family': 'Patellidae',
#    'kingdomid': 2,
#    'eventDate': '2017-08-22 03:47:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.76,
#    'shoredistance': 36081,
#    'sst': 1.48,
#    'bathymetry': 51,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_BBL3_2017-08-21T04:08:00Z',
#    'brackish': True,
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:883',
#    'scientificName': 'Polychaeta',
#    'absence': False,
#    'dropped': False,
#    'aphiaID': 883,
#    'decimalLatitude': 69.5484,
#    'taxonID': '883',
#    'originalScientificName': 'Polychaeta',
#    'marine': True,
#    'minimumDepthInMeters': 24,
#    'phylumid': 882,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': True,
#    'countryCode': 'US',
#    'date_mid': 1503273600000,
#    'maximumDepthInMeters': 24,
#    'id': '0113c8e3-c60f-44b3-aae3-e9d5b8c0a2d9',
#    'class': 'Polychaeta',
#    'identificationReferences': 'WoRMS',
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -164.4218,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1503273600000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_BBL3_5746',
#    'kingdom': 'Animalia',
#    'date_start': 1503273600000,
#    'classid': 883,
#    'depth': 24,
#    'phylum': 'Annelida',
#    'lifeStage': 'larvae',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'kingdomid': 2,
#    'eventDate': '2017-08-21 04:08:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.94,
#    'shoredistance': 49513,
#    'sst': 1.39,
#    'bathymetry': 29,
#    'mof': None},
#   {'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:106673',
#    'scientificName': 'Brachyura',
#    'dropped': False,
#    'aphiaID': 106673,
#    'decimalLatitude': 71.8718,
#    'subclassid': 1086,
#    'phylumid': 1065,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': True,
#    'superclass': 'Multicrustacea',
#    'maximumDepthInMeters': 38,
#    'id': '013ebd7d-814a-464e-bd9d-51dc20d8fc1c',
#    'order': 'Decapoda',
#    'superclassid': 845959,
#    'infraorderid': 106673,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -164.5617,
#    'date_end': 1502755200000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML3.12_1596',
#    'suborderid': 106670,
#    'date_start': 1502755200000,
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'eventDate': '2017-08-15 19:18:00',
#    'eventID': 'AMBON_Zooplankton_2017_ML3.12_2017-08-15T19:18:00Z',
#    'brackish': True,
#    'superorder': 'Eucarida',
#    'absence': False,
#    'superorderid': 1089,
#    'taxonID': '106673',
#    'originalScientificName': 'Brachyura',
#    'marine': True,
#    'minimumDepthInMeters': 38,
#    'subphylumid': 1066,
#    'countryCode': 'US',
#    'date_mid': 1502755200000,
#    'class': 'Malacostraca',
#    'identificationReferences': 'WoRMS',
#    'suborder': 'Pleocyemata',
#    'infraorder': 'Brachyura',
#    'orderid': 1130,
#    'geodeticDatum': 'WGS84',
#    'kingdom': 'Animalia',
#    'classid': 1071,
#    'depth': 38,
#    'phylum': 'Arthropoda',
#    'lifeStage': 'zoea',
#    'subphylum': 'Crustacea',
#    'subclass': 'Eumalacostraca',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'kingdomid': 2,
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.71,
#    'shoredistance': 196811,
#    'sst': -0.21,
#    'bathymetry': 40,
#    'mof': None},
#   {'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:254722',
#    'scientificName': 'Oikopleura (Vexillaria) vanhoeffeni',
#    'dropped': False,
#    'aphiaID': 103417,
#    'decimalLatitude': 71.4804,
#    'phylumid': 1821,
#    'familyid': 103356,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': False,
#    'tribeid': 343701,
#    'maximumDepthInMeters': 42,
#    'id': '015cf70e-4ed6-4bb5-8d7d-2aa432b47b4d',
#    'order': 'Copelata',
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -162.5925,
#    'date_end': 1502755200000,
#    'speciesid': 103417,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML5.9_8784',
#    'date_start': 1502755200000,
#    'genus': 'Oikopleura',
#    'tribe': 'Labiata',
#    'samplingProtocol': 'BONGO_505UM_MICROSCOPY',
#    'eventDate': '2017-08-15 02:29:00',
#    'eventID': 'AMBON_Zooplankton_2017_ML5.9_2017-08-15T02:29:00Z',
#    'brackish': False,
#    'absence': False,
#    'subfamily': 'Oikopleurinae',
#    'genusid': 103367,
#    'taxonID': '254722',
#    'originalScientificName': 'Oikopleura vanhoffeni',
#    'marine': True,
#    'minimumDepthInMeters': 42,
#    'subphylumid': 146420,
#    'subfamilyid': 342464,
#    'countryCode': 'US',
#    'date_mid': 1502755200000,
#    'subgenus': 'Oikopleura (Vexillaria)',
#    'class': 'Appendicularia',
#    'identificationReferences': 'WoRMS',
#    'orderid': 103353,
#    'geodeticDatum': 'WGS84',
#    'kingdom': 'Animalia',
#    'subgenusid': 343702,
#    'classid': 146421,
#    'depth': 42,
#    'phylum': 'Chordata',
#    'species': 'Oikopleura (Vexillaria) vanhoeffeni',
#    'subphylum': 'Tunicata',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'family': 'Oikopleuridae',
#    'kingdomid': 2,
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.65,
#    'shoredistance': 130324,
#    'sst': -0.15,
#    'bathymetry': 44,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_ML4.3_2017-08-22T03:47:00Z',
#    'brackish': True,
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:1082',
#    'scientificName': 'Cirripedia',
#    'absence': False,
#    'dropped': False,
#    'aphiaID': 1082,
#    'decimalLatitude': 71.0638,
#    'subclassid': 1082,
#    'taxonID': '1082',
#    'originalScientificName': 'Cirripedia',
#    'marine': True,
#    'minimumDepthInMeters': 55,
#    'phylumid': 1065,
#    'subphylumid': 1066,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'countryCode': 'US',
#    'superclass': 'Multicrustacea',
#    'date_mid': 1503360000000,
#    'maximumDepthInMeters': 55,
#    'id': '01651513-2d64-40b7-af8e-641b5a27c73a',
#    'class': 'Thecostraca',
#    'identificationReferences': 'WoRMS',
#    'superclassid': 845959,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -159.8822,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1503360000000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML4.3_6666',
#    'kingdom': 'Animalia',
#    'date_start': 1503360000000,
#    'classid': 22388,
#    'depth': 55,
#    'phylum': 'Arthropoda',
#    'lifeStage': 'cyprid',
#    'subphylum': 'Crustacea',
#    'subclass': 'Cirripedia',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'kingdomid': 2,
#    'eventDate': '2017-08-22 03:47:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.71,
#    'shoredistance': 30009,
#    'sst': 0,
#    'bathymetry': 55,
#    'mof': None},
#   {'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:106738',
#    'scientificName': 'Paguridae',
#    'superfamilyid': 106687,
#    'dropped': False,
#    'aphiaID': 106738,
#    'decimalLatitude': 71.994,
#    'subclassid': 1086,
#    'phylumid': 1065,
#    'familyid': 106738,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'superclass': 'Multicrustacea',
#    'maximumDepthInMeters': 39,
#    'id': '016a3e3c-2956-43e6-a690-9c2c9bee4ba0',
#    'order': 'Decapoda',
#    'superclassid': 845959,
#    'infraorderid': 106671,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -164.9421,
#    'date_end': 1502755200000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML3.13_6423',
#    'superfamily': 'Paguroidea',
#    'suborderid': 106670,
#    'date_start': 1502755200000,
#    'samplingProtocol': 'BONGO_505UM_MICROSCOPY',
#    'eventDate': '2017-08-15 17:04:00',
#    'eventID': 'AMBON_Zooplankton_2017_ML3.13_2017-08-15T17:04:00Z',
#    'superorder': 'Eucarida',
#    'absence': False,
#    'superorderid': 1089,
#    'taxonID': '106738',
#    'originalScientificName': 'Paguridae',
#    'marine': True,
#    'minimumDepthInMeters': 39,
#    'subphylumid': 1066,
#    'countryCode': 'US',
#    'date_mid': 1502755200000,
#    'class': 'Malacostraca',
#    'identificationReferences': 'WoRMS',
#    'suborder': 'Pleocyemata',
#    'infraorder': 'Anomura',
#    'orderid': 1130,
#    'geodeticDatum': 'WGS84',
#    'kingdom': 'Animalia',
#    'classid': 1071,
#    'depth': 39,
#    'phylum': 'Arthropoda',
#    'lifeStage': 'zoea',
#    'subphylum': 'Crustacea',
#    'subclass': 'Eumalacostraca',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'family': 'Paguridae',
#    'kingdomid': 2,
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.72,
#    'shoredistance': 215242,
#    'sst': -0.17,
#    'bathymetry': 39,
#    'mof': None},
#   {'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:103417',
#    'scientificName': 'Oikopleura (Vexillaria) vanhoeffeni',
#    'dropped': False,
#    'aphiaID': 103417,
#    'decimalLatitude': 70.524,
#    'phylumid': 1821,
#    'familyid': 103356,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': False,
#    'tribeid': 343701,
#    'maximumDepthInMeters': 42,
#    'id': '0174c12e-66e7-40e1-b91f-3c650e21cdc8',
#    'order': 'Copelata',
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -164.1259,
#    'date_end': 1503014400000,
#    'speciesid': 103417,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML1.5_3587',
#    'date_start': 1503014400000,
#    'genus': 'Oikopleura',
#    'tribe': 'Labiata',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'eventDate': '2017-08-18 01:33:00',
#    'eventID': 'AMBON_Zooplankton_2017_ML1.5_2017-08-18T01:33:00Z',
#    'brackish': False,
#    'absence': False,
#    'subfamily': 'Oikopleurinae',
#    'genusid': 103367,
#    'taxonID': '103417',
#    'originalScientificName': 'Oikopleura vanhoeffeni',
#    'marine': True,
#    'minimumDepthInMeters': 42,
#    'subphylumid': 146420,
#    'subfamilyid': 342464,
#    'countryCode': 'US',
#    'date_mid': 1503014400000,
#    'subgenus': 'Oikopleura (Vexillaria)',
#    'class': 'Appendicularia',
#    'identificationReferences': 'WoRMS',
#    'orderid': 103353,
#    'geodeticDatum': 'WGS84',
#    'kingdom': 'Animalia',
#    'subgenusid': 343702,
#    'classid': 146421,
#    'depth': 42,
#    'phylum': 'Chordata',
#    'species': 'Oikopleura (Vexillaria) vanhoeffeni',
#    'subphylum': 'Tunicata',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'family': 'Oikopleuridae',
#    'kingdomid': 2,
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.83,
#    'shoredistance': 76098,
#    'sst': 0.89,
#    'bathymetry': 44,
#    'mof': None},
#   {'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:106738',
#    'scientificName': 'Paguridae',
#    'superfamilyid': 106687,
#    'dropped': False,
#    'aphiaID': 106738,
#    'decimalLatitude': 71.2318,
#    'subclassid': 1086,
#    'phylumid': 1065,
#    'familyid': 106738,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'superclass': 'Multicrustacea',
#    'maximumDepthInMeters': 44,
#    'id': '01791f3d-e1ab-416b-8101-dee7fc4cb5d1',
#    'order': 'Decapoda',
#    'superclassid': 845959,
#    'infraorderid': 106671,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -162.6267,
#    'date_end': 1502841600000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML3.7_3779',
#    'superfamily': 'Paguroidea',
#    'suborderid': 106670,
#    'date_start': 1502841600000,
#    'samplingProtocol': 'BONGO_505UM_MICROSCOPY',
#    'eventDate': '2017-08-16 11:47:00',
#    'eventID': 'AMBON_Zooplankton_2017_ML3.7_2017-08-16T11:47:00Z',
#    'superorder': 'Eucarida',
#    'absence': False,
#    'superorderid': 1089,
#    'taxonID': '106738',
#    'originalScientificName': 'Paguridae',
#    'marine': True,
#    'minimumDepthInMeters': 44,
#    'subphylumid': 1066,
#    'countryCode': 'US',
#    'date_mid': 1502841600000,
#    'class': 'Malacostraca',
#    'identificationReferences': 'WoRMS',
#    'suborder': 'Pleocyemata',
#    'infraorder': 'Anomura',
#    'orderid': 1130,
#    'geodeticDatum': 'WGS84',
#    'kingdom': 'Animalia',
#    'classid': 1071,
#    'depth': 44,
#    'phylum': 'Arthropoda',
#    'lifeStage': 'zoea',
#    'subphylum': 'Crustacea',
#    'subclass': 'Eumalacostraca',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'family': 'Paguridae',
#    'kingdomid': 2,
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.68,
#    'shoredistance': 104047,
#    'sst': 0.08,
#    'bathymetry': 47,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_ML1.1_2017-08-17T15:24:00Z',
#    'brackish': True,
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:14260',
#    'scientificName': 'Rotifera',
#    'absence': False,
#    'dropped': False,
#    'aphiaID': 14260,
#    'decimalLatitude': 70.0357,
#    'taxonID': '1426',
#    'originalScientificName': 'Rotifera',
#    'marine': True,
#    'minimumDepthInMeters': 13,
#    'phylumid': 14260,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': True,
#    'countryCode': 'US',
#    'date_mid': 1502928000000,
#    'maximumDepthInMeters': 13,
#    'id': '01a85cfa-69fe-41ef-8b9e-2611009c4e60',
#    'identificationReferences': 'WoRMS',
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -162.766,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1502928000000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML1.1_4052',
#    'kingdom': 'Animalia',
#    'date_start': 1502928000000,
#    'depth': 13,
#    'phylum': 'Rotifera',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'kingdomid': 2,
#    'eventDate': '2017-08-17 15:24:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 32.38,
#    'shoredistance': 5432,
#    'sst': 1,
#    'bathymetry': 15,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_BBL3_2017-08-21T04:08:00Z',
#    'brackish': True,
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:1082',
#    'scientificName': 'Cirripedia',
#    'absence': False,
#    'dropped': False,
#    'aphiaID': 1082,
#    'decimalLatitude': 69.5484,
#    'subclassid': 1082,
#    'taxonID': '1082',
#    'originalScientificName': 'Cirripedia',
#    'marine': True,
#    'minimumDepthInMeters': 24,
#    'phylumid': 1065,
#    'subphylumid': 1066,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'countryCode': 'US',
#    'superclass': 'Multicrustacea',
#    'date_mid': 1503273600000,
#    'maximumDepthInMeters': 24,
#    'id': '01ab9c43-2d3e-43f1-a239-260d28370264',
#    'class': 'Thecostraca',
#    'identificationReferences': 'WoRMS',
#    'superclassid': 845959,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -164.4218,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1503273600000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_BBL3_2514',
#    'kingdom': 'Animalia',
#    'date_start': 1503273600000,
#    'classid': 22388,
#    'depth': 24,
#    'phylum': 'Arthropoda',
#    'lifeStage': 'nauplii',
#    'subphylum': 'Crustacea',
#    'subclass': 'Cirripedia',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'kingdomid': 2,
#    'eventDate': '2017-08-21 04:08:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.94,
#    'shoredistance': 49513,
#    'sst': 1.39,
#    'bathymetry': 29,
#    'mof': None},
#   {'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:254453',
#    'scientificName': 'Themisto pacifica',
#    'superfamilyid': 155696,
#    'dropped': False,
#    'aphiaID': 254453,
#    'decimalLatitude': 70.9718,
#    'subclassid': 1086,
#    'parvorder': 'Physocephalatidira',
#    'phylumid': 1065,
#    'familyid': 101417,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': False,
#    'superclass': 'Multicrustacea',
#    'maximumDepthInMeters': 44,
#    'id': '01adf056-f760-47e2-abd3-3d7cd7e4ba15',
#    'order': 'Amphipoda',
#    'superclassid': 845959,
#    'infraorderid': 155692,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -161.9024,
#    'date_end': 1502841600000,
#    'speciesid': 254453,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML3.5_2172',
#    'superfamily': 'Phronimoidea',
#    'suborderid': 1205,
#    'date_start': 1502841600000,
#    'genus': 'Themisto',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'eventDate': '2017-08-16 18:40:00',
#    'eventID': 'AMBON_Zooplankton_2017_ML3.5_2017-08-16T18:40:00Z',
#    'brackish': False,
#    'superorder': 'Peracarida',
#    'absence': False,
#    'superorderid': 1090,
#    'genusid': 101800,
#    'taxonID': '254453',
#    'originalScientificName': 'Themisto pacifica',
#    'marine': True,
#    'minimumDepthInMeters': 44,
#    'subphylumid': 1066,
#    'countryCode': 'US',
#    'date_mid': 1502841600000,
#    'class': 'Malacostraca',
#    'identificationReferences': 'WoRMS',
#    'suborder': 'Hyperiidea',
#    'infraorder': 'Physocephalata',
#    'orderid': 1135,
#    'parvorderid': 1055272,
#    'geodeticDatum': 'WGS84',
#    'kingdom': 'Animalia',
#    'classid': 1071,
#    'depth': 44,
#    'phylum': 'Arthropoda',
#    'species': 'Themisto pacifica',
#    'subphylum': 'Crustacea',
#    'subclass': 'Eumalacostraca',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'family': 'Hyperiidae',
#    'kingdomid': 2,
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.7,
#    'shoredistance': 71492,
#    'sst': 0.32,
#    'bathymetry': 45,
#    'mof': None},
#   {'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:104108',
#    'scientificName': 'Acartia',
#    'dropped': False,
#    'aphiaID': 104108,
#    'decimalLatitude': 67.7835,
#    'subclassid': 1080,
#    'phylumid': 1065,
#    'familyid': 104074,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': False,
#    'superclass': 'Multicrustacea',
#    'maximumDepthInMeters': 48,
#    'id': '01ba2295-262f-4b58-b2c0-5e3193c345e3',
#    'order': 'Calanoida',
#    'superclassid': 845959,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -168.605,
#    'date_end': 1503360000000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_DBO3.7_2999',
#    'date_start': 1503360000000,
#    'genus': 'Acartia',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'eventDate': '2017-08-22 03:47:00',
#    'eventID': 'AMBON_Zooplankton_2017_DBO3.7_2017-08-22T03:47:00Z',
#    'brackish': False,
#    'superorder': 'Gymnoplea',
#    'absence': False,
#    'superorderid': 155877,
#    'genusid': 104108,
#    'taxonID': '104108',
#    'originalScientificName': 'Acartia',
#    'marine': True,
#    'minimumDepthInMeters': 48,
#    'subphylumid': 1066,
#    'infraclassid': 155876,
#    'countryCode': 'US',
#    'date_mid': 1503360000000,
#    'infraclass': 'Neocopepoda',
#    'class': 'Hexanauplia',
#    'identificationReferences': 'WoRMS',
#    'orderid': 1100,
#    'geodeticDatum': 'WGS84',
#    'kingdom': 'Animalia',
#    'classid': 889925,
#    'depth': 48,
#    'phylum': 'Arthropoda',
#    'subphylum': 'Crustacea',
#    'subclass': 'Copepoda',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'family': 'Acartiidae',
#    'kingdomid': 2,
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 32.11,
#    'shoredistance': 95833,
#    'sst': 1.04,
#    'bathymetry': 47,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_ML3.14_2017-08-15T13:22:00Z',
#    'brackish': True,
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:1135',
#    'superorder': 'Peracarida',
#    'scientificName': 'Amphipoda',
#    'absence': False,
#    'dropped': False,
#    'superorderid': 1090,
#    'aphiaID': 1135,
#    'decimalLatitude': 72.1206,
#    'subclassid': 1086,
#    'taxonID': '1135',
#    'originalScientificName': 'Amphipoda',
#    'marine': True,
#    'minimumDepthInMeters': 43,
#    'phylumid': 1065,
#    'subphylumid': 1066,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': True,
#    'countryCode': 'US',
#    'superclass': 'Multicrustacea',
#    'date_mid': 1502755200000,
#    'maximumDepthInMeters': 43,
#    'id': '01c260ba-ca03-474a-a7fb-b145932bfd52',
#    'class': 'Malacostraca',
#    'order': 'Amphipoda',
#    'identificationReferences': 'WoRMS',
#    'superclassid': 845959,
#    'orderid': 1135,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -165.3536,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1502755200000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML3.14_5880',
#    'kingdom': 'Animalia',
#    'date_start': 1502755200000,
#    'classid': 1071,
#    'depth': 43,
#    'phylum': 'Arthropoda',
#    'subphylum': 'Crustacea',
#    'subclass': 'Eumalacostraca',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'BONGO_505UM_MICROSCOPY',
#    'kingdomid': 2,
#    'eventDate': '2017-08-15 13:22:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.75,
#    'shoredistance': 234716,
#    'sst': -0.13,
#    'bathymetry': 46,
#    'mof': None},
#   {'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:106777',
#    'scientificName': 'Hippolytidae',
#    'superfamilyid': 106709,
#    'dropped': False,
#    'aphiaID': 106777,
#    'decimalLatitude': 70.3697,
#    'subclassid': 1086,
#    'phylumid': 1065,
#    'familyid': 106777,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'superclass': 'Multicrustacea',
#    'maximumDepthInMeters': 43,
#    'id': '01c488d5-9e84-4e9a-a6ef-dc962d9f0922',
#    'order': 'Decapoda',
#    'superclassid': 845959,
#    'infraorderid': 106674,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -168.285,
#    'date_end': 1503360000000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_BBL12_6435',
#    'superfamily': 'Alpheoidea',
#    'suborderid': 106670,
#    'date_start': 1503360000000,
#    'samplingProtocol': 'BONGO_505UM_MICROSCOPY',
#    'eventDate': '2017-08-22 13:56:00',
#    'eventID': 'AMBON_Zooplankton_2017_BBL12_2017-08-22T13:56:00Z',
#    'superorder': 'Eucarida',
#    'absence': False,
#    'superorderid': 1089,
#    'taxonID': '106777',
#    'originalScientificName': 'Hippolytidae',
#    'marine': True,
#    'minimumDepthInMeters': 43,
#    'subphylumid': 1066,
# ...
#    'superclassid': 845959,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -166.9102,
#    'date_end': 1503360000000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_BBL9_6097',
#    'date_start': 1503360000000,
#    'genus': 'Calanus',
#    'samplingProtocol': 'BONGO_505UM_MICROSCOPY',
#    'eventDate': '2017-08-22 04:28:00',
#    'eventID': 'AMBON_Zooplankton_2017_BBL9_2017-08-22T04:28:00Z',
#    'brackish': False,
#    'superorder': 'Gymnoplea',
#    'absence': False,
#    'superorderid': 155877,
#    'genusid': 104152,
#    'taxonID': '104465',
#    'originalScientificName': 'Calanus glacialis/marshallae',
#    'marine': True,
#    'minimumDepthInMeters': 45,
#    'subphylumid': 1066,
#    'infraclassid': 155876,
#    'countryCode': 'US',
#    'date_mid': 1503360000000,
#    'infraclass': 'Neocopepoda',
#    'class': 'Hexanauplia',
#    'identificationReferences': 'WoRMS',
#    'orderid': 1100,
#    'geodeticDatum': 'WGS84',
#    'kingdom': 'Animalia',
#    'classid': 889925,
#    'depth': 45,
#    'phylum': 'Arthropoda',
#    'subphylum': 'Crustacea',
#    'subclass': 'Copepoda',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'family': 'Calanidae',
#    'kingdomid': 2,
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.84,
#    'shoredistance': 138022,
#    'sst': 1.09,
#    'bathymetry': 50,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_BBL9_2017-08-22T04:28:00Z',
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:1128',
#    'superorder': 'Eucarida',
#    'scientificName': 'Euphausiacea',
#    'absence': False,
#    'dropped': False,
#    'superorderid': 1089,
#    'aphiaID': 1128,
#    'decimalLatitude': 70.0992,
#    'subclassid': 1086,
#    'taxonID': '1128',
#    'originalScientificName': 'Euphausiacea',
#    'marine': True,
#    'minimumDepthInMeters': 45,
#    'phylumid': 1065,
#    'subphylumid': 1066,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'countryCode': 'US',
#    'superclass': 'Multicrustacea',
#    'date_mid': 1503360000000,
#    'maximumDepthInMeters': 45,
#    'id': '3474029a-a2f9-4193-8d58-e3619fe3ff0a',
#    'class': 'Malacostraca',
#    'order': 'Euphausiacea',
#    'identificationReferences': 'WoRMS',
#    'superclassid': 845959,
#    'orderid': 1128,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -166.9102,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1503360000000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_BBL9_5949',
#    'kingdom': 'Animalia',
#    'date_start': 1503360000000,
#    'classid': 1071,
#    'depth': 45,
#    'phylum': 'Arthropoda',
#    'lifeStage': 'furcilia',
#    'subphylum': 'Crustacea',
#    'subclass': 'Eumalacostraca',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'BONGO_505UM_MICROSCOPY',
#    'kingdomid': 2,
#    'eventDate': '2017-08-22 04:28:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.84,
#    'shoredistance': 138022,
#    'sst': 1.09,
#    'bathymetry': 50,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_ML5.1_2017-08-20T09:50:00Z',
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:123084',
#    'scientificName': 'Ophiuroidea',
#    'absence': False,
#    'dropped': False,
#    'aphiaID': 123084,
#    'decimalLatitude': 70.648,
#    'taxonID': '123084',
#    'originalScientificName': 'Ophiuroidea',
#    'marine': True,
#    'minimumDepthInMeters': 40,
#    'phylumid': 1806,
#    'subphylumid': 148743,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'countryCode': 'US',
#    'date_mid': 1503187200000,
#    'maximumDepthInMeters': 40,
#    'id': '3484c925-13cf-4e1b-a84d-66fa9dfd58f6',
#    'class': 'Ophiuroidea',
#    'identificationReferences': 'WoRMS',
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -165.9955,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1503187200000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML5.1_6514',
#    'kingdom': 'Animalia',
#    'date_start': 1503187200000,
#    'classid': 123084,
#    'depth': 40,
#    'phylum': 'Echinodermata',
#    'lifeStage': 'larvae',
#    'subphylum': 'Asterozoa',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'kingdomid': 2,
#    'eventDate': '2017-08-20 09:50:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.83,
#    'shoredistance': 143466,
#    'sst': 0.88,
#    'bathymetry': 42,
#    'mof': None},
#   {'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:196772',
#    'scientificName': 'Neocalanus plumchrus',
#    'dropped': False,
#    'aphiaID': 196772,
#    'decimalLatitude': 71.5847,
#    'subclassid': 1080,
#    'phylumid': 1065,
#    'familyid': 104079,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': False,
#    'superclass': 'Multicrustacea',
#    'maximumDepthInMeters': 45,
#    'id': '348b92eb-8e64-4f4e-b6e5-39c0dcc0e629',
#    'order': 'Calanoida',
#    'superclassid': 845959,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -161.4087,
#    'date_end': 1502582400000,
#    'speciesid': 196772,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML4.7_3815',
#    'date_start': 1502582400000,
#    'genus': 'Neocalanus',
#    'samplingProtocol': 'BONGO_505UM_MICROSCOPY',
#    'eventDate': '2017-08-13 02:11:00',
#    'eventID': 'AMBON_Zooplankton_2017_ML4.7_2017-08-13T02:11:00Z',
#    'brackish': False,
#    'superorder': 'Gymnoplea',
#    'absence': False,
#    'superorderid': 155877,
#    'genusid': 104155,
#    'taxonID': '196772',
#    'originalScientificName': 'Neocalanus plumchrus',
#    'marine': True,
#    'minimumDepthInMeters': 45,
#    'subphylumid': 1066,
#    'infraclassid': 155876,
#    'countryCode': 'US',
#    'date_mid': 1502582400000,
#    'infraclass': 'Neocopepoda',
#    'class': 'Hexanauplia',
#    'identificationReferences': 'WoRMS',
#    'orderid': 1100,
#    'geodeticDatum': 'WGS84',
#    'kingdom': 'Animalia',
#    'classid': 889925,
#    'depth': 45,
#    'phylum': 'Arthropoda',
#    'species': 'Neocalanus plumchrus',
#    'subphylum': 'Crustacea',
#    'subclass': 'Copepoda',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'family': 'Calanidae',
#    'kingdomid': 2,
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.57,
#    'shoredistance': 108023,
#    'sst': -0.32,
#    'bathymetry': 47,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_BBL4_2017-08-21T08:30:00Z',
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:1128',
#    'superorder': 'Eucarida',
#    'scientificName': 'Euphausiacea',
#    'absence': False,
#    'dropped': False,
#    'superorderid': 1089,
#    'aphiaID': 1128,
#    'decimalLatitude': 69.6413,
#    'subclassid': 1086,
#    'taxonID': '1128',
#    'originalScientificName': 'Euphausiacea',
#    'marine': True,
#    'minimumDepthInMeters': 29,
#    'phylumid': 1065,
#    'subphylumid': 1066,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'countryCode': 'US',
#    'superclass': 'Multicrustacea',
#    'date_mid': 1503273600000,
#    'maximumDepthInMeters': 29,
#    'id': '349a150f-664c-4bb2-826c-6374d70f8786',
#    'class': 'Malacostraca',
#    'order': 'Euphausiacea',
#    'identificationReferences': 'WoRMS',
#    'superclassid': 845959,
#    'orderid': 1128,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -164.811,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1503273600000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_BBL4_6879',
#    'kingdom': 'Animalia',
#    'date_start': 1503273600000,
#    'classid': 1071,
#    'depth': 29,
#    'phylum': 'Arthropoda',
#    'lifeStage': 'furcilia',
#    'subphylum': 'Crustacea',
#    'subclass': 'Eumalacostraca',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'kingdomid': 2,
#    'eventDate': '2017-08-21 08:30:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.85,
#    'shoredistance': 64343,
#    'sst': 1.41,
#    'bathymetry': 30,
#    'mof': None},
#   {'infraphylum': 'Gnathostomata',
#    'eventID': 'AMBON_Zooplankton_2017_ML1.6_2017-08-18T06:01:00Z',
#    'brackish': True,
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:11676',
#    'scientificName': 'Pisces',
#    'absence': False,
#    'dropped': False,
#    'aphiaID': 11676,
#    'decimalLatitude': 70.6464,
#    'taxonID': '11676',
#    'infraphylumid': 1828,
#    'originalScientificName': 'Pisces',
#    'marine': True,
#    'minimumDepthInMeters': 44,
#    'phylumid': 1821,
#    'subphylumid': 146419,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'countryCode': 'US',
#    'superclass': 'Pisces',
#    'date_mid': 1503014400000,
#    'maximumDepthInMeters': 44,
#    'id': '349a74a3-676c-4758-a80a-bc3d969dcc5a',
#    'identificationReferences': 'WoRMS',
#    'superclassid': 11676,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -164.4836,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1503014400000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML1.6_5263',
#    'kingdom': 'Animalia',
#    'date_start': 1503014400000,
#    'depth': 44,
#    'phylum': 'Chordata',
#    'lifeStage': 'larvae',
#    'subphylum': 'Vertebrata',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'BONGO_505UM_MICROSCOPY',
#    'kingdomid': 2,
#    'eventDate': '2017-08-18 06:01:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': ['no_accepted_name'],
#    'sss': 31.79,
#    'shoredistance': 94517,
#    'sst': 0.81,
#    'bathymetry': 46,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_BBL3_2017-08-21T04:08:00Z',
#    'brackish': False,
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:105440',
#    'scientificName': 'Parasagitta elegans',
#    'absence': False,
#    'dropped': False,
#    'genusid': 105408,
#    'aphiaID': 105440,
#    'decimalLatitude': 69.5484,
#    'taxonID': '10544',
#    'originalScientificName': 'Parasagitta elegans',
#    'marine': True,
#    'minimumDepthInMeters': 24,
#    'phylumid': 2081,
#    'familyid': 5953,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': False,
#    'countryCode': 'US',
#    'date_mid': 1503273600000,
#    'maximumDepthInMeters': 24,
#    'id': '349b20b5-bd33-4971-9372-8b7106cbb734',
#    'class': 'Sagittoidea',
#    'order': 'Aphragmophora',
#    'identificationReferences': 'WoRMS',
#    'orderid': 5950,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -164.4218,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1503273600000,
#    'speciesid': 105440,
#    'occurrenceID': 'AMBON_Zooplankton_2017_BBL3_6198',
#    'kingdom': 'Animalia',
#    'date_start': 1503273600000,
#    'classid': 5949,
#    'depth': 24,
#    'phylum': 'Chaetognatha',
#    'genus': 'Parasagitta',
#    'species': 'Parasagitta elegans',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'family': 'Sagittidae',
#    'kingdomid': 2,
#    'eventDate': '2017-08-21 04:08:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.94,
#    'shoredistance': 49513,
#    'sst': 1.39,
#    'bathymetry': 29,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_ML4.1_2017-08-12T11:00:00Z',
#    'brackish': True,
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:1806',
#    'scientificName': 'Echinodermata',
#    'absence': False,
#    'dropped': False,
#    'aphiaID': 1806,
#    'decimalLatitude': 70.8908,
#    'taxonID': '1806',
#    'originalScientificName': 'Echinodermata',
#    'marine': True,
#    'minimumDepthInMeters': 27,
#    'phylumid': 1806,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'countryCode': 'US',
#    'date_mid': 1502496000000,
#    'maximumDepthInMeters': 27,
#    'id': '349cb194-2732-484e-bcd1-2ee1b354e0f1',
#    'identificationReferences': 'WoRMS',
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -159.3972,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1502496000000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML4.1_6353',
#    'kingdom': 'Animalia',
#    'date_start': 1502496000000,
#    'depth': 27,
#    'phylum': 'Echinodermata',
#    'lifeStage': 'bipinnaria',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'TWINRING_150UM_MICROSCOPY',
#    'kingdomid': 2,
#    'eventDate': '2017-08-12 11:00:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.85,
#    'shoredistance': 5068,
#    'sst': 0.05,
#    'bathymetry': 27,
#    'mof': None},
#   {'eventID': 'AMBON_Zooplankton_2017_ML6.3_2017-08-09T18:49:00Z',
#    'brackish': False,
#    'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:117743',
#    'scientificName': 'Melicertum octocostatum',
#    'absence': False,
#    'dropped': False,
#    'genusid': 117152,
#    'aphiaID': 117743,
#    'decimalLatitude': 70.3891,
#    'subclassid': 19494,
#    'taxonID': '117743',
#    'originalScientificName': 'Melicertum octocostatum',
#    'marine': True,
#    'minimumDepthInMeters': 30,
#    'phylumid': 1267,
#    'familyid': 22798,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'terrestrial': False,
#    'countryCode': 'US',
#    'date_mid': 1502236800000,
#    'maximumDepthInMeters': 30,
#    'id': '349d520d-30b2-4895-ad85-430b18698d38',
#    'class': 'Hydrozoa',
#    'order': 'Leptothecata',
#    'identificationReferences': 'WoRMS',
#    'orderid': 13552,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -163.0304,
#    'geodeticDatum': 'WGS84',
#    'date_end': 1502236800000,
#    'speciesid': 117743,
#    'occurrenceID': 'AMBON_Zooplankton_2017_ML6.3_8734',
#    'kingdom': 'Animalia',
#    'date_start': 1502236800000,
#    'classid': 1337,
#    'depth': 30,
#    'phylum': 'Cnidaria',
#    'genus': 'Melicertum',
#    'species': 'Melicertum octocostatum',
#    'subclass': 'Hydroidolina',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'samplingProtocol': 'BONGO_505UM_MICROSCOPY',
#    'family': 'Melicertidae',
#    'kingdomid': 2,
#    'eventDate': '2017-08-09 18:49:00',
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 32,
#    'shoredistance': 33978,
#    'sst': 0.98,
#    'bathymetry': 30,
#    'mof': None},
#   {'date_year': 2017,
#    'scientificNameID': 'urn:lsid:marinespecies.org:taxname:106777',
#    'scientificName': 'Hippolytidae',
#    'superfamilyid': 106709,
#    'dropped': False,
#    'aphiaID': 106777,
#    'decimalLatitude': 68.009,
#    'subclassid': 1086,
#    'phylumid': 1065,
#    'familyid': 106777,
#    'occurrenceStatus': 'present',
#    'basisOfRecord': 'HumanObservation',
#    'superclass': 'Multicrustacea',
#    'maximumDepthInMeters': 51,
#    'id': '34a146e7-fdb9-4eb8-a0d3-96c2d25fcb7b',
#    'order': 'Decapoda',
#    'superclassid': 845959,
#    'infraorderid': 106674,
#    'dataset_id': 'bc01451e-d990-4ad1-8315-e3fb6e9cf461',
#    'decimalLongitude': -167.8681,
#    'date_end': 1502064000000,
#    'occurrenceID': 'AMBON_Zooplankton_2017_DBO3.5_1720',
#    'superfamily': 'Alpheoidea',
#    'suborderid': 106670,
#    'date_start': 1502064000000,
#    'samplingProtocol': 'BONGO_505UM_MICROSCOPY',
#    'eventDate': '2017-08-07 05:34:00',
#    'eventID': 'AMBON_Zooplankton_2017_DBO3.5_2017-08-07T05:34:00Z',
#    'superorder': 'Eucarida',
#    'absence': False,
#    'superorderid': 1089,
#    'taxonID': '106777',
#    'originalScientificName': 'Hippolytidae',
#    'marine': True,
#    'minimumDepthInMeters': 51,
#    'subphylumid': 1066,
#    'countryCode': 'US',
#    'date_mid': 1502064000000,
#    'class': 'Malacostraca',
#    'identificationReferences': 'WoRMS',
#    'suborder': 'Pleocyemata',
#    'infraorder': 'Caridea',
#    'orderid': 1130,
#    'geodeticDatum': 'WGS84',
#    'kingdom': 'Animalia',
#    'classid': 1071,
#    'depth': 51,
#    'phylum': 'Arthropoda',
#    'subphylum': 'Crustacea',
#    'subclass': 'Eumalacostraca',
#    'datasetID': 'AMBON_Zooplankton_2017',
#    'family': 'Hippolytidae',
#    'kingdomid': 2,
#    'node_id': ['b7c47783-a020-4173-b390-7b57c4fa1426'],
#    'flags': [],
#    'sss': 31.93,
#    'shoredistance': 56112,
#    'sst': 1.27,
#    'bathymetry': 53,
#    'mof': None},
#   ...]}

# %%
f'{GBIF_URL}/dataset/{GBIF_UUID}'
# Out:
# 'https://api.gbif.org/v1/dataset/7afb6dbd-6485-42c2-aee7-c730bd81d2cd'

# %%
import pandas as pd

df_all = pd.DataFrame()

for result in req.json()['results']:
    #print(result)
    df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in result.items() ]))
    df_all = pd.concat([df_all, df], ignore_index=True)
# Out:
# C:\Users\MATHEW~1.BID\AppData\Local\Temp\17/ipykernel_9772/1564230861.py:7: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in result.items() ]))

# %%
df_all.columns
# Out:
# Index(['date_year', 'scientificNameID', 'scientificName', 'dropped', 'aphiaID',
#        'decimalLatitude', 'phylumid', 'familyid', 'occurrenceStatus',
#        'basisOfRecord', 'tribeid', 'maximumDepthInMeters', 'id', 'order',
#        'dataset_id', 'decimalLongitude', 'date_end', 'speciesid',
#        'occurrenceID', 'date_start', 'genus', 'tribe', 'samplingProtocol',
#        'eventDate', 'eventID', 'absence', 'subfamily', 'genusid', 'taxonID',
#        'originalScientificName', 'marine', 'minimumDepthInMeters',
#        'subphylumid', 'subfamilyid', 'countryCode', 'date_mid', 'subgenus',
#        'class', 'identificationReferences', 'orderid', 'geodeticDatum',
#        'kingdom', 'subgenusid', 'classid', 'depth', 'phylum', 'species',
#        'subphylum', 'datasetID', 'family', 'kingdomid', 'node_id', 'flags',
#        'sss', 'shoredistance', 'sst', 'bathymetry', 'mof', 'subclassid',
#        'terrestrial', 'subclass', 'superclass', 'superclassid', 'brackish',
#        'superorder', 'superorderid', 'infraclassid', 'infraclass', 'lifeStage',
#        'suborderid', 'suborder', 'superfamilyid', 'superfamily',
#        'infraorderid', 'infraorder', 'parvorder', 'parvorderid', 'sex',
#        'subterclassid', 'subterclass', 'subspecies', 'subspeciesid', 'section',
#        'subsection', 'sectionid', 'subsectionid', 'infraphylum',
#        'infraphylumid', 'wrims', 'infrakingdomid', 'subkingdom',
#        'infrakingdom', 'subkingdomid'],
#       dtype='object')

# %%
df_all['mof']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 4763    NaN
# 4764    NaN
# 4765    NaN
# 4766    NaN
# 4767    NaN
# Name: mof, Length: 4768, dtype: object

# %%
df_all.shape
# Out:
# (4768, 93)
