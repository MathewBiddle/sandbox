# %%
import pandas as pd

# %%
df = pd.read_csv('mbon-modules-layergroups-export.csv')

# %%
df['module.creation_time'] = pd.to_datetime(df['module.creation_time'])
df['module.start_time_utc'] = pd.to_datetime(df['module.start_time_utc'])
df['module.end_time_utc'] = pd.to_datetime(df['module.end_time_utc'])

# %%
df[['module.creation_time','module.start_time_utc','module.end_time_utc']].describe(datetime_is_numeric=True).T
# Out:
#                       count                          mean                 min  \
# module.creation_time    729 2017-04-19 15:14:50.452675072 2015-03-23 19:49:00
# module.start_time_utc   212 1999-10-04 02:35:54.339622656 1899-12-29 15:00:00
# module.end_time_utc     212 2014-04-07 09:55:52.924528384 2002-03-02 00:00:00
#
#                                       25%                 50%  \
# module.creation_time  2015-03-23 19:49:00 2016-05-02 18:20:00
# module.start_time_utc 1974-09-15 00:00:00 2010-02-15 12:00:00
# module.end_time_utc   2002-03-02 00:00:00 2017-12-26 00:00:00
#
#                                       75%                 max
# module.creation_time  2019-03-28 16:35:00 2021-03-25 13:33:00
# module.start_time_utc 2016-04-30 00:00:00 2019-05-05 00:00:00
# module.end_time_utc   2019-09-29 12:00:00 2021-04-12 17:00:00

# %%
df
# Out:
#                                           module.label  \
# 0                                     Alaska ShoreZone
# 1                                     Alaska ShoreZone
# 2                                     Alaska ShoreZone
# 3                                     Alaska ShoreZone
# 4                                     Alaska ShoreZone
# ..                                                 ...
# 724               National Marine Sanctuary Boundaries
# 725  Santa Barbara Channel Marine Biodiversity Obse...
# 726          SECOORA Fisheries and Wildlife Monitoring
# 727          SECOORA Fisheries and Wildlife Monitoring
# 728                          SECOORA Real-time Sensors
#
#                                     module.description module.creation_time  \
# 0    ShoreZone is a coastal habitat mapping and cla...  2015-03-23 19:49:00
# 1    ShoreZone is a coastal habitat mapping and cla...  2015-03-23 19:49:00
# ...
