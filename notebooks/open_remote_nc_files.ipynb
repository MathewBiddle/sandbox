# %%
import xarray as xr
import urllib

# %%
url = 'http://52.55.122.42/thredds/dodsC/buoys/RealTime/PR2/DSG_PR2.accelerometer2.realtime.nc'

#f = xr.open_dataset(urllib.urlretrieve('https://www.nodc.noaa.gov/archive/arc0118/0171315/26.26/data/0-data/air_temperature.nc'))

# if error NetCDF: Not a valid data type or _FillValue type mismatch add '#fillmismatch' to url
f = xr.open_dataset(url+'#fillmismatch')

f
# Out:
# <xarray.Dataset>
# Dimensions:                       (time: 5864)
# Coordinates:
#   * time                          (time) datetime64[ns] 2021-05-28T15:30:00.0...
#     lon                           float32 ...
#     lat                           float32 ...
#     depth                         float32 ...
# Data variables:
#     station                       |S64 ...
#     significant_wave_height_2     (time) float32 ...
#     significant_wave_height_2_qc  (time) float32 ...
#     dominant_wave_period_2        (time) float32 ...
#     dominant_wave_period_2_qc     (time) float32 ...
#     time_created                  (time) datetime64[ns] ...
#     time_modified                 (time) datetime64[ns] ...
# Attributes: (12/69)
#     title:                           Department of Physical Oceanography, Sch...
#     institution:                     Department of Physical Oceanography, Sch...
#     institution_url:                 http://gyre.umeoce.maine.edu
# ...

# %%
f.significant_wave_height_2.plot()
