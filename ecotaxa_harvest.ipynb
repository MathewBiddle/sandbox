# %% [markdown]
# <a href="https://colab.research.google.com/github/MathewBiddle/sandbox/blob/main/ecotaxa_harvest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Harvesting data from EcoTaxa API
#
# Documentation: https://ecotaxa.obs-vlfr.fr/api/docs#/
#
# MBON Project to harvest: https://ecotaxa.obs-vlfr.fr/prj/9989

# %%
import pandas as pd
import json
import urllib.request

# %%
project_id = "9989"
for_managing = "true" #false

url_add = f'https://ecotaxa.obs-vlfr.fr/api/projects/{project_id}?for_managing={for_managing}'

with urllib.request.urlopen(url_add) as url:
    data = json.load(url)

print(f'{url_add}')
data
# Out:
# https://ecotaxa.obs-vlfr.fr/api/projects/9989?for_managing=true
# {'projid': 9989,
#  'title': 'SFER_SEMBON_CPICS_manual',
#  'visible': True,
#  'access': '2',
#  'status': 'Annotate',
#  'objcount': 11464.0,
#  'pctvalidated': 19.050942079553383,
#  'pctclassified': 19.050942079553383,
#  'classifsettings': None,
#  'classiffieldlist': '',
#  'popoverfieldlist': 'img_file_name, object_id, object_date, object_time, object_lat, object_lon, object_depth_min, object_depth_max',
#  'comments': 'Images in this project are manually annotated ',
#  'description': 'This project contributes plankton imagery collected with a CPICS mounted on a CTD-rosette during oceanographic surveys carried out by the South Florida Ecosystem Restoration program led by NOAA AOML and the SE Marine Biodiversity Observation Network (SE-MBON) project. Imagery profiles are collected along the Florida Keys and the west Florida shelf, from Miami to Tampa Bay, every ~6 weeks aboard the R/V Walton Smith of the University of Miami and occasionally using vessels from the Florida Institute of Oceanography (FIO).',
#  'rf_models_used': None,
#  'cnn_network_id': '',
#  'formulae': None,
#  'obj_free_cols': {'major': 'n01',
#   'minor': 'n02',
#   'area': 'n03',
#   'circularity': 'n04',
#   'perimeter': 'n05',
#   'width': 'n06',
#   'height': 'n07',
#   'sharpness': 'n08',
#   'saturation': 'n09',
#   'redness': 'n10',
#   'greeness': 'n11',
#   'blueness': 'n12',
#   'colorfulness': 'n13'},
#  'sample_free_cols': {},
#  'acquisition_free_cols': {'author': 't01'},
#  'process_free_cols': {},
#  'bodc_variables': {'subsample_coef': None,
#   'individual_volume': None,
#   'total_water_volume': None},
#  'init_classif_list': [11762,
#   85123,
#   85708,
#   85196,
#   11514,
#   28280,
#   11509,
#   56066,
#   30815,
#   94677,
#   85538,
#   56079,
#   56074,
#   28223,
#   28285,
#   11864,
#   11861,
#   94035,
#   93944,
#   85031,
#   93950,
#   85004],
#  'managers': [{'id': 1861,
#    'email': 'enrique.montes@noaa.gov',
#    'name': 'Enrique Montes',
#    'organisation': 'U. Miami CIMAS / NOAA AOML'},
#   {'id': 2698,
#    'email': 'joaquin.trinanes@noaa.gov',
#    'name': 'Joaquin Trinanes',
#    'organisation': 'NOAA-AOML'}],
#  'annotators': [{'id': 1465,
#    'email': 'janheu@uio.no',
#    'name': 'Jan Heuschele',
#    'organisation': 'University of Oslo'},
#   {'id': 2093,
#    'email': 'ankita.vaswani@hereon.de',
#    'name': 'Ankita Vaswani',
#    'organisation': 'Helmholtz-Zentrum Geesthacht Centre for Materials and Coastal Research - HZG'},
#   {'id': 2208,
#    'email': 'jennifer.wolny@fda.hhs.gov',
#    'name': 'Jennifer Wolny',
#    'organisation': 'US Food and Drug Administration'},
#   {'id': 2209,
#    'email': 'chris.kelble@noaa.gov',
#    'name': 'Christopher Kelble',
#    'organisation': 'National Oceanic and Atmospheric Administration'},
#   {'id': 2210,
#    'email': 'tyler.christian@noaa.gov',
#    'name': 'Tyler Christian',
#    'organisation': 'U. Miami CIMAS / NOAA AOML'},
#   {'id': 2211,
#    'email': 'carib@usf.edu',
#    'name': 'Frank Muller-Karger',
#    'organisation': 'University of South Florida'},
#   {'id': 2249,
#    'email': 'jhon.mojica@noaa.gov',
#    'name': 'Jhon Mojica',
#    'organisation': 'NOAA-AOML'},
#   {'id': 2501,
#    'email': 'nmillette@vims.edu',
#    'name': 'Nicole Millette',
#    'organisation': 'Virginia Institute of Marine Science - VIMS'},
#   {'id': 3143,
#    'email': 'lara.zadeh@gmail.com',
#    'name': 'Lara Zadeh',
#    'organisation': 'NOAA'}],
#  'viewers': [],
#  'contact': {'id': 1861,
#   'email': 'enrique.montes@noaa.gov',
#   'name': 'Enrique Montes',
#   'organisation': 'U. Miami CIMAS / NOAA AOML'},
#  'instrument': 'CPICS',
#  'instrument_url': 'http://vocab.nerc.ac.uk/collection/L22/current/TOOL1582/',
#  'highest_right': ''}

# %%
# !pip install git+https://github.com/ecotaxa/ecotaxa_py_client.git
# Out:
# Collecting git+https://github.com/ecotaxa/ecotaxa_py_client.git
#   Cloning https://github.com/ecotaxa/ecotaxa_py_client.git to /tmp/pip-req-build-xaujgwb6
#   Running command git clone --filter=blob:none --quiet https://github.com/ecotaxa/ecotaxa_py_client.git /tmp/pip-req-build-xaujgwb6
#   Resolved https://github.com/ecotaxa/ecotaxa_py_client.git to commit 07e8545befa9c14006d11c15dafa71b3259f62f9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting urllib3<2.1.0,>=1.25.3 (from ecotaxa_py_client==2.0.5)
#   Downloading urllib3-2.0.7-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from ecotaxa_py_client==2.0.5) (2.9.0.post0)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.11/dist-packages (from ecotaxa_py_client==2.0.5) (2.11.4)
# Requirement already satisfied: typing-extensions>=4.7.1 in /usr/local/lib/python3.11/dist-packages (from ecotaxa_py_client==2.0.5) (4.13.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ecotaxa_py_client==2.0.5) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ecotaxa_py_client==2.0.5) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ecotaxa_py_client==2.0.5) (0.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->ecotaxa_py_client==2.0.5) (1.17.0)
# Downloading urllib3-2.0.7-py3-none-any.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 kB 7.1 MB/s eta 0:00:00
# Building wheels for collected packages: ecotaxa_py_client
#   Building wheel for ecotaxa_py_client (pyproject.toml) ... done
#   Created wheel for ecotaxa_py_client: filename=ecotaxa_py_client-2.0.5-py3-none-any.whl size=191964 sha256=1ffc4e03cd4c8c9fa5154978f3eb44411db64475473847875c8cfcdf89c42ab0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jr5iclf7/wheels/00/b7/43/9f033e4796890ad57d6131bc246517583c5718ee6a05717ea4
# Successfully built ecotaxa_py_client
# Installing collected packages: urllib3, ecotaxa_py_client
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.4.0
#     Uninstalling urllib3-2.4.0:
#       Successfully uninstalled urllib3-2.4.0
# Successfully installed ecotaxa_py_client-2.0.5 urllib3-2.0.7

# %%
import ecotaxa_py_client
from ecotaxa_py_client.models.body_export_object_set_summary_object_set_export_summary_post import BodyExportObjectSetSummaryObjectSetExportSummaryPost
from ecotaxa_py_client.models.export_rsp import ExportRsp
from ecotaxa_py_client.rest import ApiException
from pprint import pprint
import os
# Defining the host is optional and defaults to https://ecotaxa.obs-vlfr.fr/api
# See configuration.py for a list of all supported configuration parameters.
configuration = ecotaxa_py_client.Configuration(
    host = "https://ecotaxa.obs-vlfr.fr/api"
)

# The client must configure the authentication and authorization parameters
# in accordance with the API server security policy.
# Examples for each auth method are provided below, use the example that
# satisfies your auth use case.

configuration.access_token = os.environ["ACCESS_TOKEN"]

# Enter a context with an instance of the API client
with ecotaxa_py_client.ApiClient(configuration) as api_client:
    # Create an instance of the API class
    api_instance = ecotaxa_py_client.ObjectsApi(api_client)
    body_export_object_set_summary_object_set_export_summary_post = ecotaxa_py_client.BodyExportObjectSetSummaryObjectSetExportSummaryPost() # BodyExportObjectSetSummaryObjectSetExportSummaryPost |

    try:
        # Export Object Set Summary
        api_response = api_instance.export_object_set_summary(body_export_object_set_summary_object_set_export_summary_post)
        print("The response of ObjectsApi->export_object_set_summary:\n")
        pprint(api_response)
    except Exception as e:
        print("Exception when calling ObjectsApi->export_object_set_summary: %s\n" % e)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-b2c682c87111> in <cell line: 0>()
#      16 # satisfies your auth use case.
#      17
# ---> 18 configuration.access_token = os.environ["ACCESS_TOKEN"]
#      19
#      20 # Enter a context with an instance of the API client
#
# /usr/lib/python3.11/os.py in __getitem__(self, key)
#
# KeyError: 'ACCESS_TOKEN'

# %%
import ecotaxa_py_client

# %%
10543+43
# Out:
# 10586
